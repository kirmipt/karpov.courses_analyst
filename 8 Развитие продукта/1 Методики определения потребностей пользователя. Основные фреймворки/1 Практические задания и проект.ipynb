# %% [markdown]
# ## 1. “Как Саша, я хочу организовать своё собственное расписание, чтобы успевать больше”. Эта формулировка соответствует методу:
#
# * **Personas**
# * JTBD
# * Value Proposition Canvas
# * **User Story** (производная Personas)
#
# ## 2. “Когда я хожу в спортзал, я хочу носить красивую спортивную форму, чтобы мне делали комплименты”. Эта формулировка соответствует:
#
# * User Story
# * Value Proposition Canvas
# * Personas
# * **JTBD**
#
# ## 3. Карта эмпатии помогает:
#
# * **Лучше понимать ЦА продукта**
# * **Подготовиться к пользовательскому интервью**
# * **Синхронизироваться со стейкхолдерами(заинтересованными лицами) в представлении о пользователях**
# * Увидеть путь пользователя в продукте (этапы это JTBD)
# * **Отразить результаты интервью**
# * **Зафиксировать свои галлюцинации относительно пользователей**
#
# ## 4. Напишите 3 JTBD для сервиса по доставке продуктов «Самокат»
#
# 1. When я живу далеко от магазина I want to заказывать продукты So I can тратить больше времени на профессиональный рост
# 2. When я захожу в приложение доставки I want to иметь удобный функционал So I can пользоваться этим приложением а не искать другое удобнее
# <br>_приложение, конкуренция_
# 3. When я делаю заказ продуктов, I want to, чтобы все необходимое было доставлено без ошибок и вовремя, So I can не тратить свое время на разрешение неприятной ситуации.
# <br>_качество_
